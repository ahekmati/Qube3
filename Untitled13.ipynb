# %%
import numpy as np 
A = np.array([
    [4, -5, 6],
    [7, -8, 6],
    [1.5, -0.5, -2]])

vals, vecs = np.linalg.eig(A)

print(vals)
print(vecs)
# Out:
# [ 1. -4. -3.]
# [[-0.6882472  -0.66666667  0.40824829]
#  [-0.6882472  -0.66666667 -0.40824829]
#  [-0.22941573  0.33333333 -0.81649658]]
